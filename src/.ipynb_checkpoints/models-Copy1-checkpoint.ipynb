# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/Drug_Consumption.csv')

# remove ID column and semeron (fictitious drug introduced to identify over-claimers)
df.drop('ID', axis = 1, inplace = True)
df.drop('Semer', axis = 1, inplace = True)

# remove country column, reason see report
df.drop('Country', axis = 1, inplace = True)

# df.head()

# %%
all_subs = set(df.columns[13:])

# used legal substance within in last WEEK or more frequent: 1, otherwise: 0
legal = {'Alcohol', 'Caff', 'Choc', 'Legalh', 'Nicotine'}
mapping_legal = {'CL0': 0, 'CL1': 0, 'CL2': 0, 'CL3': 0, 'CL4': 0, 'CL5': 1, 'CL6': 1}
for subs in legal:
    df = df.replace({subs: mapping_legal})

# used illegal substance within in last YEAR or more frequent: 1, otherwise: 0
illegal = all_subs - legal
# print(illegal)
mapping_illegal = {'CL0': 0, 'CL1': 0, 'CL2': 0, 'CL3': 1, 'CL4': 1, 'CL5': 1, 'CL6': 1}
for subs in illegal:
    df = df.replace({subs: mapping_legal})
    
# target variable
df['NumIllegal']= df[list(illegal)].sum(axis=1)

# clean up dataframe
df.drop(list(illegal), axis = 1, inplace = True)

y = df['NumIllegal']
X = df.loc[:, df.columns != 'NumIllegal']

# %%
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
import pickle

# %%
# baseline RMSE
baseline_pred = np.ones(len(y))*np.mean(y)
baseline_pred_round = np.ones(len(y))*np.round(np.mean(y))

baseline_RMSE = np.sqrt(mean_squared_error(y,baseline_pred))
print('The baseline root mean squared error is:', baseline_RMSE)

baseline_accuracy = accuracy_score(y,np.zeros(len(y))) # predict class 0 for all points
print('The baseline accuracy is:', baseline_accuracy)

baseline_acc_from_mean = accuracy_score(y, baseline_pred_round) # predict rounded mean for all points
print('The baseline accuracy of rounded mean is:', baseline_acc_from_mean)
# Out:
# The baseline root mean squared error is: 1.0003076054677795
# The baseline accuracy is: 0.5658174097664543
# The baseline accuracy of rounded mean is: 0.25796178343949044

# %%
# getting ready for preprocessing
ordinal_ftrs = ['Age','Education']
ordinal_cats = [['18-24', '25-34', '35-44', '45-54', '55-64', '65+'], \
                ['Left school before 16 years', 'Left school at 16 years', 'Left school at 17 years',\
                'Left school at 18 years', 'Some college or university, no certificate or degree',\
                'Professional certificate/ diploma', 'University degree', 'Masters degree', 'Doctorate degree']]

onehot_ftrs = ['Gender','Ethnicity']

std_ftrs = ['Nscore', 'Escore', 'Oscore', 'AScore', 'Cscore', 'Impulsive', 'SS']

prep = ColumnTransformer(
    transformers=[
        ('ord', OrdinalEncoder(categories = ordinal_cats), ordinal_ftrs),
        ('onehot', OneHotEncoder(sparse=False,handle_unknown='ignore',drop='if_binary'), onehot_ftrs),
        ('std', StandardScaler(), std_ftrs)])

# %%
# function
def MLpipe_KFold_RMSE(X, y, clf, param_grid, model_name):    
    num_rs = 10
    test_RMSE = np.zeros(num_rs)
    test_accuracy = np.zeros(num_rs)
    final_models = []
    
    for rs in range(num_rs):

        # 80 train and validation, 20 test
        X_other, X_test, y_other, y_test = train_test_split(X, y, test_size = 0.2, random_state = rs)

        # K fold on other
        kf = KFold(n_splits = 4, shuffle = True, random_state = rs)
    
        # preprocess
        X_other = prep.fit_transform(X_other)
        X_test = prep.transform(X_test)

        # standard scale all features
        scaler = StandardScaler()
        X_other = scaler.fit_transform(X_other)
        X_test = scaler.transform(X_test)
        
        # GridSearchCV
        try:
            model = clf(random_state = rs)
        except:
            model = clf()
        pipe = make_pipeline(model)
    
        grid = GridSearchCV(pipe, param_grid, scoring = 'neg_root_mean_squared_error',
                            cv=kf, return_train_score = True, n_jobs=-1, verbose=True)

        grid.fit(X_other, y_other)
        # results = pd.DataFrame(grid.cv_results_)
        # print(results)

        print('Best model parameters:',grid.best_params_)
        print('Validation RMSE score:',-grid.best_score_) # turn neg_root_mean_squared_error positive
        final_models.append(grid)
        
        # calculate and save the test RMSE
        y_test_pred = final_models[-1].predict(X_test)
        test_RMSE[rs] =  np.sqrt(mean_squared_error(y_test,y_test_pred))
        print('Test RMSE score:',test_RMSE[rs])
        
        # round regression prediction
        y_test_pred_rounded = np.round(y_test_pred)
        test_accuracy[rs] = accuracy_score(y_test, y_test_pred_rounded)
        
        model_rs = model_name + '_' + str(rs)
        file = open('../results/dump/%s.save' %model_rs, 'wb+')
        pickle.dump((grid,X_test,y_test,y_test_pred),file)
        file.close()
        
        feature_names = prep.get_feature_names_out()
        
    return final_models, test_RMSE, test_accuracy, feature_names

# %%
# initialize dictionaries to save test scores
all_RMSE = {}
all_RMSE_std = {}
all_RMSE_std_below = {}

all_acc = {}
all_acc_std = {}
all_acc_std_above = {}

# %%
# Model 1: elastic net

from sklearn.linear_model import ElasticNet
clf = ElasticNet

param_grid = {
              'elasticnet__alpha': [0.05, 0.1, 0.5],
              'elasticnet__l1_ratio': [0.05, 0.1, 0.2, 0.4],
              'elasticnet__max_iter': [3000]
              } 

model_name = 'ElasticNet'
final_models, test_RMSE, test_accuracy, feature_names = MLpipe_KFold_RMSE(X, y, clf, param_grid, model_name)

all_RMSE[model_name] = np.mean(test_RMSE)
print('\nMean of test RMSE score:', np.mean(all_RMSE[model_name]))

all_RMSE_std[model_name] = np.std(test_RMSE)
print('Standard deviation of test RMSE score:', all_RMSE_std[model_name])

all_RMSE_std_below[model_name] = (baseline_RMSE - all_RMSE[model_name]) / all_RMSE_std[model_name]
print('Test RMSE score is', all_RMSE_std_below[model_name], 'standard deviations below the baseline')

all_acc[model_name] = np.mean(test_accuracy)
print('\nMean of test accuracy of rounded prediction:', all_acc[model_name])

all_acc_std[model_name] = np.std(test_accuracy)
print('Standard deviation of test accuracy of rounded prediction:', all_acc_std[model_name])

if baseline_accuracy < all_acc[model_name]:
    all_acc_std_above[model_name] = (all_acc[model_name] - baseline_accuracy) / all_acc_std[model_name]
    print('Test accuracy is', all_acc_std_above[model_name], 'standard deviations above the baseline')
else: 
    print('Test accuracy is below baseline')
# Out:
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.05, 'elasticnet__max_iter': 3000}
# Validation RMSE score: 0.8655296609068636
# Test RMSE score: 0.8787463971592298
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'elasticnet__alpha': 0.05, 'elasticnet__l1_ratio': 0.2, 'elasticnet__max_iter': 3000}
# Validation RMSE score: 0.8660884251691328
# Test RMSE score: 0.8635463993168303
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'elasticnet__alpha': 0.05, 'elasticnet__l1_ratio': 0.2, 'elasticnet__max_iter': 3000}
# Validation RMSE score: 0.8683337050033243
# Test RMSE score: 0.8539780395694703
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'elasticnet__alpha': 0.05, 'elasticnet__l1_ratio': 0.05, 'elasticnet__max_iter': 3000}
# Validation RMSE score: 0.8534814049067896
# ...

# %%
# Model 2: KNN regressor 

from sklearn.neighbors import KNeighborsRegressor
clf = KNeighborsRegressor

param_grid = {
              'kneighborsregressor__n_neighbors': [80, 100, 120, 140, 160],
              'kneighborsregressor__weights': ['uniform', 'distance']
              } 

model_name = 'KNeighborsRegressor'
final_models, test_RMSE, test_accuracy, feature_names = MLpipe_KFold_RMSE(X, y, clf, param_grid, model_name)

all_RMSE[model_name] = np.mean(test_RMSE)
print('\nMean of test RMSE score:', np.mean(all_RMSE[model_name]))

all_RMSE_std[model_name] = np.std(test_RMSE)
print('Standard deviation of test RMSE score:', all_RMSE_std[model_name])

all_RMSE_std_below[model_name] = (baseline_RMSE - all_RMSE[model_name]) / all_RMSE_std[model_name]
print('Test RMSE score is', all_RMSE_std_below[model_name], 'standard deviations below the baseline')

all_acc[model_name] = np.mean(test_accuracy)
print('\nMean of test accuracy of rounded prediction:', all_acc[model_name])

all_acc_std[model_name] = np.std(test_accuracy)
print('Standard deviation of test accuracy of rounded prediction:', all_acc_std[model_name])

if baseline_accuracy < all_acc[model_name]:
    all_acc_std_above[model_name] = (all_acc[model_name] - baseline_accuracy) / all_acc_std[model_name]
    print('Test accuracy is', all_acc_std_above[model_name], 'standard deviations above the baseline')
else: 
    print('Test accuracy is below baseline')
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# Best model parameters: {'kneighborsregressor__n_neighbors': 100, 'kneighborsregressor__weights': 'uniform'}
# Validation RMSE score: 0.8592578217155433
# Test RMSE score: 0.8747339117958234
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# Best model parameters: {'kneighborsregressor__n_neighbors': 100, 'kneighborsregressor__weights': 'distance'}
# Validation RMSE score: 0.8614074472198373
# Test RMSE score: 0.8546926112795833
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# Best model parameters: {'kneighborsregressor__n_neighbors': 100, 'kneighborsregressor__weights': 'distance'}
# Validation RMSE score: 0.864044077317241
# Test RMSE score: 0.8549481675646217
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# Best model parameters: {'kneighborsregressor__n_neighbors': 100, 'kneighborsregressor__weights': 'distance'}
# Validation RMSE score: 0.848129477556479
# ...

# %%
# Model 3: random forest regressor

from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor

param_grid = {
              'randomforestregressor__max_depth': [5, 10, 15],
              'randomforestregressor__max_features': [0.1, 0.3, 0.5, 0.7]
              }

model_name = 'RandomForestRegressor'
final_models, test_RMSE, test_accuracy, feature_names = MLpipe_KFold_RMSE(X, y, clf, param_grid, model_name)

all_RMSE[model_name] = np.mean(test_RMSE)
print('\nMean of test RMSE score:', np.mean(all_RMSE[model_name]))

all_RMSE_std[model_name] = np.std(test_RMSE)
print('Standard deviation of test RMSE score:', all_RMSE_std[model_name])

all_RMSE_std_below[model_name] = (baseline_RMSE - all_RMSE[model_name]) / all_RMSE_std[model_name]
print('Test RMSE score is', all_RMSE_std_below[model_name], 'standard deviations below the baseline')

all_acc[model_name] = np.mean(test_accuracy)
print('\nMean of test accuracy of rounded prediction:', all_acc[model_name])

all_acc_std[model_name] = np.std(test_accuracy)
print('Standard deviation of test accuracy of rounded prediction:', all_acc_std[model_name])

if baseline_accuracy < all_acc[model_name]:
    all_acc_std_above[model_name] = (all_acc[model_name] - baseline_accuracy) / all_acc_std[model_name]
    print('Test accuracy is', all_acc_std_above[model_name], 'standard deviations above the baseline')
else: 
    print('Test accuracy is below baseline')
# Out:
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'randomforestregressor__max_depth': 15, 'randomforestregressor__max_features': 0.1}
# Validation RMSE score: 0.8678531802251367
# Test RMSE score: 0.8615650318000379
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'randomforestregressor__max_depth': 5, 'randomforestregressor__max_features': 0.3}
# Validation RMSE score: 0.865987854401489
# Test RMSE score: 0.8628579413678096
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'randomforestregressor__max_depth': 5, 'randomforestregressor__max_features': 0.5}
# Validation RMSE score: 0.8709386621066749
# Test RMSE score: 0.8544456738987937
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'randomforestregressor__max_depth': 15, 'randomforestregressor__max_features': 0.1}
# Validation RMSE score: 0.8503364932293354
# ...

# %%
# Model 4: support vector regressor 

from sklearn.svm import SVR

clf = SVR

param_grid = {
              'svr__gamma': [0.001, 0.01, 0.1],
              'svr__C': [0.1, 1, 10, 100]
              }

model_name = 'SVR'
final_models, test_RMSE, test_accuracy, feature_names = MLpipe_KFold_RMSE(X, y, clf, param_grid, model_name)

all_RMSE[model_name] = np.mean(test_RMSE)
print('\nMean of test RMSE score:', np.mean(all_RMSE[model_name]))

all_RMSE_std[model_name] = np.std(test_RMSE)
print('Standard deviation of test RMSE score:', all_RMSE_std[model_name])

all_RMSE_std_below[model_name] = (baseline_RMSE - all_RMSE[model_name]) / all_RMSE_std[model_name]
print('Test RMSE score is', all_RMSE_std_below[model_name], 'standard deviations below the baseline')

all_acc[model_name] = np.mean(test_accuracy)
print('\nMean of test accuracy of rounded prediction:', all_acc[model_name])

all_acc_std[model_name] = np.std(test_accuracy)
print('Standard deviation of test accuracy of rounded prediction:', all_acc_std[model_name])

if baseline_accuracy < all_acc[model_name]:
    all_acc_std_above[model_name] = (all_acc[model_name] - baseline_accuracy) / all_acc_std[model_name]
    print('Test accuracy is', all_acc_std_above[model_name], 'standard deviations above the baseline')
else: 
    print('Test accuracy is below baseline')
# Out:
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'svr__C': 1, 'svr__gamma': 0.01}
# Validation RMSE score: 0.8910727641079165
# Test RMSE score: 0.9031699236602029
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'svr__C': 1, 'svr__gamma': 0.1}
# Validation RMSE score: 0.8854149551118602
# Test RMSE score: 0.8922476217810731
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'svr__C': 100, 'svr__gamma': 0.001}
# Validation RMSE score: 0.8950274243408738
# Test RMSE score: 0.8700294583752554
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'svr__C': 1, 'svr__gamma': 0.01}
# Validation RMSE score: 0.876068153858639
# Test RMSE score: 0.9476293726531149
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# Best model parameters: {'svr__C': 1, 'svr__gamma': 0.01}
# Validation RMSE score: 0.8979804727748443
# ...

# %%
# Model 5: xgb regressor

from xgboost import XGBRegressor
import warnings
warnings.filterwarnings("ignore")

clf = XGBRegressor

param_grid = {'xgbregressor__learning_rate': [0.01, 0.03, 0.05], #so called `eta` value
              'xgbregressor__max_depth': [1, 5, 10],
              'xgbregressor__n_estimators': [100], #number of trees, change it to 1000 for better results
              'xgbregressor__use_label_encoder': [False],
              'xgbregressor__eval_metric': ['rmse']
             }

model_name = 'XGBRegressor'

final_models, test_RMSE, test_accuracy, feature_names = MLpipe_KFold_RMSE(X, y, clf, param_grid, model_name)

all_RMSE[model_name] = np.mean(test_RMSE)
print('\nMean of test RMSE score:', np.mean(all_RMSE[model_name]))

all_RMSE_std[model_name] = np.std(test_RMSE)
print('Standard deviation of test RMSE score:', all_RMSE_std[model_name])

all_RMSE_std_below[model_name] = (baseline_RMSE - all_RMSE[model_name]) / all_RMSE_std[model_name]
print('Test RMSE score is', all_RMSE_std_below[model_name], 'standard deviations below the baseline')

all_acc[model_name] = np.mean(test_accuracy)
print('\nMean of test accuracy of rounded prediction:', all_acc[model_name])

all_acc_std[model_name] = np.std(test_accuracy)
print('Standard deviation of test accuracy of rounded prediction:', all_acc_std[model_name])

if baseline_accuracy < all_acc[model_name]:
    all_acc_std_above[model_name] = (all_acc[model_name] - baseline_accuracy) / all_acc_std[model_name]
    print('Test accuracy is', all_acc_std_above[model_name], 'standard deviations above the baseline')
else: 
    print('Test accuracy is below baseline')
# Out:
# Fitting 4 folds for each of 9 candidates, totalling 36 fits
# /Users/zhangchengyue/opt/anaconda3/envs/data1030_env/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/zhangchengyue/opt/anaconda3/envs/data1030_env/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/zhangchengyue/opt/anaconda3/envs/data1030_env/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# ...

# %%
print('Mean of test RMSE score for each model: ', all_RMSE)
# print('Standard deviation of test RMSE score for each model:' , all_test_RMSE_std)
print('Mean accuracy of rounded prediction for each model: ', all_acc)
# Out:
# Mean of test RMSE score for each model:  {'ElasticNet': 0.8592580434497069, 'KNeighborsRegressor': 0.8566195272125124, 'RandomForestRegressor': 0.8628622498156624, 'SVR': 0.88698995985932, 'XGBRegressor': 0.8703399667594995}
# Mean accuracy of rounded prediction for each model:  {'ElasticNet': 0.5225464190981433, 'KNeighborsRegressor': 0.5607427055702918, 'RandomForestRegressor': 0.5522546419098143, 'SVR': 0.6114058355437665, 'XGBRegressor': 0.5456233421750663}

# %%
import matplotlib
from matplotlib import pylab as plt

# %%
plt.plot()
plt.errorbar(list(all_RMSE.keys()), list(all_RMSE.values()), list(all_RMSE_std.values()), fmt='.k', markersize=10)
plt.axhline(y = baseline_RMSE, color = 'r', linestyle = '-', label = 'baseline')
plt.legend(loc = 'lower right')
plt.xticks(rotation=30, ha='right')
plt.xlabel('model names')
plt.ylabel('mean of test RMSE and its standard deviation')
plt.title('RMSE of different models')
plt.show()

# %%
plt.plot()
plt.errorbar(list(all_acc.keys()), list(all_acc.values()), list(all_acc_std.values()), fmt='.k', markersize=10)
plt.axhline(y = baseline_accuracy, color = 'r', linestyle = '-', label = 'baseline')
plt.legend(loc = 'lower right')
plt.xticks(rotation=30, ha='right')
plt.xlabel('model names')
plt.ylabel('mean of test accuracy and its standard deviation')
plt.title('Accuracy of rounded prediction of different models')
plt.show()

# %%
# global feature importance of SVR calculated with permutation importance
from sklearn.inspection import permutation_importance

file = open('../results/SVC_0.save', 'rb') 
model,X_test,y_test,y_test_pred = pickle.load(file) 
file.close()

result = permutation_importance(estimator=model, X=X_test, y=y_test, scoring = 'accuracy', n_repeats=10, random_state=6)

sorted_idx = result.importances_mean.argsort()[-10:]

plt.boxplot(result.importances[sorted_idx].T,labels=feature_names[sorted_idx],vert=False)
plt.title('Permutation importances of SVR (test set)')
plt.xlabel('difference between permuted test score and true test score ')
plt.show()

# %%
# global feature importance of SVR calculated with shap
import shap
shap.initjs()
explainer = shap.KernelExplainer(model.best_estimator_[0].predict, shap.sample(X_test, 10))

# calculate shap values on all points in the test set
shap_values = explainer.shap_values(shap.sample(X_test, 10))
shap.summary_plot(shap_values, X_test, feature_names = feature_names, max_display = 10, plot_type = 'bar', show = False)
plt.title('Global feature importance of SVR measured by shap values')
plt.show()

# %%
# global feature importance of XGBClassifier calculated with permutation importance
file = open('../results/XGBClassifier_0.save', 'rb') 
model,X_test,y_test,y_test_pred = pickle.load(file) 
file.close()

result = permutation_importance(estimator=model, X=X_test, y=y_test, scoring = 'neg_mean_squared_error', n_repeats=10, random_state=6)

sorted_idx = result.importances_mean.argsort()[-10:]

plt.boxplot(result.importances[sorted_idx].T,labels=feature_names[sorted_idx],vert=False)
plt.title('Permutation Importances (test set)')
plt.xlabel('difference between permuted test score and true test score ')
plt.show()

# %%
# global feature importance of XGBClassifier calculated with shap
shap.initjs()
explainer = shap.TreeExplainer(model.best_estimator_[0])

# calculate shap values on all points in the test set
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test, feature_names = feature_names, max_display = 10, plot_type = 'bar', show = False)
plt.title('Global feature importance measured by shap values')
plt.show()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
print(np.shape(shap_values[1]))
print(shap_values[1])
print(y_test[5])
print(y_test_pred[5])
X_test[1].round(4)
# Out:
# (377, 17)
# [[ 0.1898677  -0.06115839  0.10485759 ...  0.03154362  0.04815467
#    0.06909013]
#  [-0.02493212  0.26355574  0.10117717 ...  0.10632203 -0.11735189
#   -0.15044965]
#  [ 0.02271177 -0.17284127 -0.16296709 ... -0.11217497  0.06613347
#    0.07948674]
#  ...
#  [ 0.11597675  0.22957343  0.03747824 ...  0.01585263  0.05233396
#    0.03927425]
#  [ 0.01616456  0.14660583  0.02683951 ...  0.06566213 -0.05103055
#    0.00965492]
#  [ 0.01849741 -0.32881445 -0.1399398  ... -0.07442133 -0.22442046
#   -0.14446364]]
# 0
# 0.5317314062858056
# array([ 0.4902, -0.5691,  1.0113, -0.1272, -0.1376, -0.0258, -0.1068,
#        -0.0968, -0.1833,  0.3111, -0.7785, -0.8098, -2.0988, -1.6636,
#        -2.2001, -2.6645, -1.2064])

# %%
print(y_test_pred)
print(y_test)
# Out:
# [ 8.32113764e-01  2.19362226e-01  1.52693211e-01  3.90658091e-01
#   1.03538418e+00  5.31731406e-01  2.12837886e-01  5.08218426e-01
#   8.12407939e-01  1.33381202e+00  3.52911992e-01  3.38778329e-02
#   9.32792874e-01  4.38741804e-01  1.64395053e-01  2.50440946e-01
#   6.75853891e-01  7.80178705e-01  7.59184888e-01  3.89934854e-01
#   3.86142557e-01 -1.71560252e-02  1.37596683e-01  9.16243484e-01
#   2.27788011e-01  4.56771524e-01  5.24106342e-01  2.28526179e-01
#   1.35296139e+00  8.56109318e-01  2.89449862e-01  1.60933094e-01
#   4.05375240e-01  6.57307166e-01 -1.00440110e-01  5.30186778e-01
#   1.06597991e-01 -3.68364979e-02  3.90245270e-01  1.27452924e+00
#   2.84587684e-01  1.43365308e+00 -1.42134446e-01  5.05323973e-01
#   1.18141245e+00  3.99676630e-01  3.10100401e-01  8.92403088e-01
#   8.50561175e-01  9.72188740e-01  4.13028307e-01  7.80209210e-01
#   7.54052899e-01  1.29522590e+00  8.28965918e-02  5.19159466e-01
# ...

# %%
index = 1
shap.force_plot(explainer.expected_value[0], shap_values[y_test[index]][index][:], features = X_test[index].round(4), feature_names = feature_names, text_rotation=10, matplotlib=True, show=False)
plt.show()

# %%
index = 4
shap.force_plot(explainer.expected_value[0], shap_values[index][0], features = X_test[index].round(4), feature_names = feature_names, text_rotation=10, matplotlib=True, show=False)
plt.show()

# %%
index = 8
shap.force_plot(explainer.expected_value[0], shap_values[index][0], features = X_test[index].round(4), feature_names = feature_names, text_rotation=10, matplotlib=True, show=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [244], line 2
#       1 index = 8
# ----> 2 shap.force_plot(explainer.expected_value[0], shap_values[index][0], features = X_test[index].round(4), feature_names = feature_names, text_rotation=10, matplotlib=True, show=False)
#       3 plt.show()
#
# IndexError: list index out of range

# %%
print(y_test)
print(np.mean(X_test[:,-5]))
print(feature_names)
# Out:
# 883     2
# 77      0
# 536     0
# 107     0
# 1190    1
#        ..
# 1399    0
# 794     1
# 823     3
# 748     2
# 518     0
# Name: NumIllegal, Length: 377, dtype: int64
# -0.036473832353793416
# ['ord__Age' 'ord__Education' 'onehot__Gender_M' 'onehot__Ethnicity_Asian'
#  'onehot__Ethnicity_Black' 'onehot__Ethnicity_Mixed-Black/Asian'
#  'onehot__Ethnicity_Mixed-White/Asian'
#  'onehot__Ethnicity_Mixed-White/Black' 'onehot__Ethnicity_Other'
#  'onehot__Ethnicity_White' 'std__Nscore' 'std__Escore' 'std__Oscore'
#  'std__AScore' 'std__Cscore' 'std__Impulsive' 'std__SS']
